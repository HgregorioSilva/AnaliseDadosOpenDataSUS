# %%
import pandas as pd
low_memory=False
# %matplotlib inline
pd.options.display.max_columns = 80
pd.options.display.max_rows = 90
from datetime import datetime
import numpy as np
import matplotlib.pyplot as plt

# %%
#Lendo arquivo de casos ano 2020
filename = r'C:\Users\henri\Desktop\Masanori\Dados07072020\INFLUD-07-07-2020.csv'
df = pd.read_csv(filename, delimiter = ';', encoding='ISO-8859-1', error_bad_lines=False)

#Lendo arquivo de casos ano 2019
filename = r'C:\Users\henri\Desktop\Masanori\2019\influd19_limpo-27.04.2020-final.csv'
df2019 = pd.read_csv(filename, delimiter = ';', encoding='ISO-8859-1', error_bad_lines=False)
# Out:
# c:\users\henri\appdata\local\programs\python\python36-32\lib\site-packages\IPython\core\interactiveshell.py:3063: DtypeWarning: Columns (18,59,61,62,63,103,105,117,119,126,128,129,130,132) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# c:\users\henri\appdata\local\programs\python\python36-32\lib\site-packages\IPython\core\interactiveshell.py:3063: DtypeWarning: Columns (97,105,107,133) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
#############################################################################################################################
##############################################PREPARAÇÃO DOS DADOS###########################################################
#############################################################################################################################

#Troca indice númerico(1,2 e 9) da evolução para um conjunto de carácter(Cura,Óbito e Ignorado) ano 2020
df.loc[(df.EVOLUCAO.isnull()), 'EVOLUCAO'] = 9
troca_evolucao = { 1: 'Cura', 2: 'Óbito', 9: 'Ignorado'}
df['EVOLUCAO'] = df['EVOLUCAO'].apply(lambda x: troca_evolucao[x])

#Troca indice númerico(1,2 e 9) da evolução para um conjunto de carácter(Cura,Óbito e Ignorado)ano 2019
df2019.loc[(df2019.EVOLUCAO.isnull()), 'EVOLUCAO'] = 9
troca_evolucao = { 1: 'Cura', 2: 'Óbito', 9: 'Ignorado'}
df2019['EVOLUCAO'] = df2019['EVOLUCAO'].apply(lambda x: troca_evolucao[x])

# %%
#############################################################################################################################
#########################################PREPARAÇÃO DOS DADOS 2020###########################################################
#############################################################################################################################

#Contagem de número de óbitos de pessoas separados por estado ano 2020
obitoAC = int(df.query('EVOLUCAO == "Óbito" and SG_UF == "AC"').groupby('SG_UF').size().sort_values())
obitoAL = int(df.query('EVOLUCAO == "Óbito" and SG_UF == "AL"').groupby('SG_UF').size().sort_values())
obitoAP = int(df.query('EVOLUCAO == "Óbito" and SG_UF == "AP"').groupby('SG_UF').size().sort_values())
obitoAM = int(df.query('EVOLUCAO == "Óbito" and SG_UF == "AM"').groupby('SG_UF').size().sort_values())
obitoBA = int(df.query('EVOLUCAO == "Óbito" and SG_UF == "BA"').groupby('SG_UF').size().sort_values())
obitoCE = int(df.query('EVOLUCAO == "Óbito" and SG_UF == "CE"').groupby('SG_UF').size().sort_values())
obitoDF = int(df.query('EVOLUCAO == "Óbito" and SG_UF == "DF"').groupby('SG_UF').size().sort_values())
obitoES = int(df.query('EVOLUCAO == "Óbito" and SG_UF == "ES"').groupby('SG_UF').size().sort_values())
obitoGO = int(df.query('EVOLUCAO == "Óbito" and SG_UF == "GO"').groupby('SG_UF').size().sort_values())
obitoMA = int(df.query('EVOLUCAO == "Óbito" and SG_UF == "MA"').groupby('SG_UF').size().sort_values())
obitoMT = int(df.query('EVOLUCAO == "Óbito" and SG_UF == "MT"').groupby('SG_UF').size().sort_values())
obitoMS = int(df.query('EVOLUCAO == "Óbito" and SG_UF == "MS"').groupby('SG_UF').size().sort_values())
obitoMG = int(df.query('EVOLUCAO == "Óbito" and SG_UF == "MG"').groupby('SG_UF').size().sort_values())
obitoPA = int(df.query('EVOLUCAO == "Óbito" and SG_UF == "PA"').groupby('SG_UF').size().sort_values())
obitoPB = int(df.query('EVOLUCAO == "Óbito" and SG_UF == "PB"').groupby('SG_UF').size().sort_values())
obitoPR = int(df.query('EVOLUCAO == "Óbito" and SG_UF == "PR"').groupby('SG_UF').size().sort_values())
obitoPE = int(df.query('EVOLUCAO == "Óbito" and SG_UF == "PE"').groupby('SG_UF').size().sort_values())
obitoPI = int(df.query('EVOLUCAO == "Óbito" and SG_UF == "PI"').groupby('SG_UF').size().sort_values())
obitoRJ = int(df.query('EVOLUCAO == "Óbito" and SG_UF == "RJ"').groupby('SG_UF').size().sort_values())
obitoRN = int(df.query('EVOLUCAO == "Óbito" and SG_UF == "RN"').groupby('SG_UF').size().sort_values())
obitoRS = int(df.query('EVOLUCAO == "Óbito" and SG_UF == "RS"').groupby('SG_UF').size().sort_values())
obitoRO = int(df.query('EVOLUCAO == "Óbito" and SG_UF == "RO"').groupby('SG_UF').size().sort_values())
obitoRR = int(df.query('EVOLUCAO == "Óbito" and SG_UF == "RR"').groupby('SG_UF').size().sort_values())
obitoSC = int(df.query('EVOLUCAO == "Óbito" and SG_UF == "SC"').groupby('SG_UF').size().sort_values())
obitoSP = int(df.query('EVOLUCAO == "Óbito" and SG_UF == "SP"').groupby('SG_UF').size().sort_values())
obitoSE = int(df.query('EVOLUCAO == "Óbito" and SG_UF == "SE"').groupby('SG_UF').size().sort_values())
obitoTO = int(df.query('EVOLUCAO == "Óbito" and SG_UF == "TO"').groupby('SG_UF').size().sort_values())

# %%
#############################################################################################################################
#########################################PREPARAÇÃO DOS DADOS 2019###########################################################
#############################################################################################################################

#Contagem de número de óbitos de pessoas separados por estado ano 2019
obitoAC2019 = int(df2019.query('EVOLUCAO == "Óbito" and SG_UF == "AC"').groupby('SG_UF').size().sort_values())
obitoAL2019 = int(df2019.query('EVOLUCAO == "Óbito" and SG_UF == "AL"').groupby('SG_UF').size().sort_values())
obitoAP2019 = int(df2019.query('EVOLUCAO == "Óbito" and SG_UF == "AP"').groupby('SG_UF').size().sort_values())
obitoAM2019 = int(df2019.query('EVOLUCAO == "Óbito" and SG_UF == "AM"').groupby('SG_UF').size().sort_values())
obitoBA2019 = int(df2019.query('EVOLUCAO == "Óbito" and SG_UF == "BA"').groupby('SG_UF').size().sort_values())
obitoCE2019 = int(df2019.query('EVOLUCAO == "Óbito" and SG_UF == "CE"').groupby('SG_UF').size().sort_values())
obitoDF2019 = int(df2019.query('EVOLUCAO == "Óbito" and SG_UF == "DF"').groupby('SG_UF').size().sort_values())
obitoES2019 = int(df2019.query('EVOLUCAO == "Óbito" and SG_UF == "ES"').groupby('SG_UF').size().sort_values())
obitoGO2019 = int(df2019.query('EVOLUCAO == "Óbito" and SG_UF == "GO"').groupby('SG_UF').size().sort_values())
obitoMA2019 = int(df2019.query('EVOLUCAO == "Óbito" and SG_UF == "MA"').groupby('SG_UF').size().sort_values())
obitoMT2019 = int(df2019.query('EVOLUCAO == "Óbito" and SG_UF == "MT"').groupby('SG_UF').size().sort_values())
obitoMS2019 = int(df2019.query('EVOLUCAO == "Óbito" and SG_UF == "MS"').groupby('SG_UF').size().sort_values())
obitoMG2019 = int(df2019.query('EVOLUCAO == "Óbito" and SG_UF == "MG"').groupby('SG_UF').size().sort_values())
obitoPA2019 = int(df2019.query('EVOLUCAO == "Óbito" and SG_UF == "PA"').groupby('SG_UF').size().sort_values())
obitoPB2019 = int(df2019.query('EVOLUCAO == "Óbito" and SG_UF == "PB"').groupby('SG_UF').size().sort_values())
obitoPR2019 = int(df2019.query('EVOLUCAO == "Óbito" and SG_UF == "PR"').groupby('SG_UF').size().sort_values())
obitoPE2019 = int(df2019.query('EVOLUCAO == "Óbito" and SG_UF == "PE"').groupby('SG_UF').size().sort_values())
obitoPI2019 = int(df2019.query('EVOLUCAO == "Óbito" and SG_UF == "PI"').groupby('SG_UF').size().sort_values())
obitoRJ2019 = int(df2019.query('EVOLUCAO == "Óbito" and SG_UF == "RJ"').groupby('SG_UF').size().sort_values())
obitoRN2019 = int(df2019.query('EVOLUCAO == "Óbito" and SG_UF == "RN"').groupby('SG_UF').size().sort_values())
obitoRS2019 = int(df2019.query('EVOLUCAO == "Óbito" and SG_UF == "RS"').groupby('SG_UF').size().sort_values())
obitoRO2019 = int(df2019.query('EVOLUCAO == "Óbito" and SG_UF == "RO"').groupby('SG_UF').size().sort_values())
obitoRR2019 = int(df2019.query('EVOLUCAO == "Óbito" and SG_UF == "RR"').groupby('SG_UF').size().sort_values())
obitoSC2019 = int(df2019.query('EVOLUCAO == "Óbito" and SG_UF == "SC"').groupby('SG_UF').size().sort_values())
obitoSP2019 = int(df2019.query('EVOLUCAO == "Óbito" and SG_UF == "SP"').groupby('SG_UF').size().sort_values())
obitoSE2019 = int(df2019.query('EVOLUCAO == "Óbito" and SG_UF == "SE"').groupby('SG_UF').size().sort_values())
obitoTO2019 = int(df2019.query('EVOLUCAO == "Óbito" and SG_UF == "TO"').groupby('SG_UF').size().sort_values())

# %%
#############################################################################################################################
#########################################PREPARAÇÃO DOS DADOS 2020###########################################################
#############################################################################################################################

#Contagem de número de pessoas curadas separados por estado ano 2020
curaAC = int(df.query('EVOLUCAO == "Cura" and SG_UF == "AC"').groupby('SG_UF').size().sort_values())
curaAL = int(df.query('EVOLUCAO == "Cura" and SG_UF == "AL"').groupby('SG_UF').size().sort_values())
curaAP = int(df.query('EVOLUCAO == "Cura" and SG_UF == "AP"').groupby('SG_UF').size().sort_values())
curaAM = int(df.query('EVOLUCAO == "Cura" and SG_UF == "AM"').groupby('SG_UF').size().sort_values())
curaBA = int(df.query('EVOLUCAO == "Cura" and SG_UF == "BA"').groupby('SG_UF').size().sort_values())
curaCE = int(df.query('EVOLUCAO == "Cura" and SG_UF == "CE"').groupby('SG_UF').size().sort_values())
curaDF = int(df.query('EVOLUCAO == "Cura" and SG_UF == "DF"').groupby('SG_UF').size().sort_values())
curaES = int(df.query('EVOLUCAO == "Cura" and SG_UF == "ES"').groupby('SG_UF').size().sort_values())
curaGO = int(df.query('EVOLUCAO == "Cura" and SG_UF == "GO"').groupby('SG_UF').size().sort_values())
curaMA = int(df.query('EVOLUCAO == "Cura" and SG_UF == "MA"').groupby('SG_UF').size().sort_values())
curaMT = int(df.query('EVOLUCAO == "Cura" and SG_UF == "MT"').groupby('SG_UF').size().sort_values())
curaMS = int(df.query('EVOLUCAO == "Cura" and SG_UF == "MS"').groupby('SG_UF').size().sort_values())
curaMG = int(df.query('EVOLUCAO == "Cura" and SG_UF == "MG"').groupby('SG_UF').size().sort_values())
curaPA = int(df.query('EVOLUCAO == "Cura" and SG_UF == "PA"').groupby('SG_UF').size().sort_values())
curaPB = int(df.query('EVOLUCAO == "Cura" and SG_UF == "PB"').groupby('SG_UF').size().sort_values())
curaPR = int(df.query('EVOLUCAO == "Cura" and SG_UF == "PR"').groupby('SG_UF').size().sort_values())
curaPE = int(df.query('EVOLUCAO == "Cura" and SG_UF == "PE"').groupby('SG_UF').size().sort_values())
curaPI = int(df.query('EVOLUCAO == "Cura" and SG_UF == "PI"').groupby('SG_UF').size().sort_values())
curaRJ = int(df.query('EVOLUCAO == "Cura" and SG_UF == "RJ"').groupby('SG_UF').size().sort_values())
curaRN = int(df.query('EVOLUCAO == "Cura" and SG_UF == "RN"').groupby('SG_UF').size().sort_values())
curaRS = int(df.query('EVOLUCAO == "Cura" and SG_UF == "RS"').groupby('SG_UF').size().sort_values())
curaRO = int(df.query('EVOLUCAO == "Cura" and SG_UF == "RO"').groupby('SG_UF').size().sort_values())
curaRR = int(df.query('EVOLUCAO == "Cura" and SG_UF == "RR"').groupby('SG_UF').size().sort_values())
curaSC = int(df.query('EVOLUCAO == "Cura" and SG_UF == "SC"').groupby('SG_UF').size().sort_values())
curaSP = int(df.query('EVOLUCAO == "Cura" and SG_UF == "SP"').groupby('SG_UF').size().sort_values())
curaSE = int(df.query('EVOLUCAO == "Cura" and SG_UF == "SE"').groupby('SG_UF').size().sort_values())
curaTO = int(df.query('EVOLUCAO == "Cura" and SG_UF == "TO"').groupby('SG_UF').size().sort_values())

# %%
#############################################################################################################################
#########################################PREPARAÇÃO DOS DADOS 2019###########################################################
#############################################################################################################################

#Contagem de número de pessoas curadas separados por estado ano 2019
curaAC2019 = int(df2019.query('EVOLUCAO == "Cura" and SG_UF == "AC"').groupby('SG_UF').size().sort_values())
curaAL2019 = int(df2019.query('EVOLUCAO == "Cura" and SG_UF == "AL"').groupby('SG_UF').size().sort_values())
curaAP2019 = int(df2019.query('EVOLUCAO == "Cura" and SG_UF == "AP"').groupby('SG_UF').size().sort_values())
curaAM2019 = int(df2019.query('EVOLUCAO == "Cura" and SG_UF == "AM"').groupby('SG_UF').size().sort_values())
curaBA2019 = int(df2019.query('EVOLUCAO == "Cura" and SG_UF == "BA"').groupby('SG_UF').size().sort_values())
curaCE2019 = int(df2019.query('EVOLUCAO == "Cura" and SG_UF == "CE"').groupby('SG_UF').size().sort_values())
curaDF2019 = int(df2019.query('EVOLUCAO == "Cura" and SG_UF == "DF"').groupby('SG_UF').size().sort_values())
curaES2019 = int(df2019.query('EVOLUCAO == "Cura" and SG_UF == "ES"').groupby('SG_UF').size().sort_values())
curaGO2019 = int(df2019.query('EVOLUCAO == "Cura" and SG_UF == "GO"').groupby('SG_UF').size().sort_values())
curaMA2019 = int(df2019.query('EVOLUCAO == "Cura" and SG_UF == "MA"').groupby('SG_UF').size().sort_values())
curaMT2019 = int(df2019.query('EVOLUCAO == "Cura" and SG_UF == "MT"').groupby('SG_UF').size().sort_values())
curaMS2019 = int(df2019.query('EVOLUCAO == "Cura" and SG_UF == "MS"').groupby('SG_UF').size().sort_values())
curaMG2019 = int(df2019.query('EVOLUCAO == "Cura" and SG_UF == "MG"').groupby('SG_UF').size().sort_values())
curaPA2019 = int(df2019.query('EVOLUCAO == "Cura" and SG_UF == "PA"').groupby('SG_UF').size().sort_values())
curaPB2019 = int(df2019.query('EVOLUCAO == "Cura" and SG_UF == "PB"').groupby('SG_UF').size().sort_values())
curaPR2019 = int(df2019.query('EVOLUCAO == "Cura" and SG_UF == "PR"').groupby('SG_UF').size().sort_values())
curaPE2019 = int(df2019.query('EVOLUCAO == "Cura" and SG_UF == "PE"').groupby('SG_UF').size().sort_values())
curaPI2019 = int(df2019.query('EVOLUCAO == "Cura" and SG_UF == "PI"').groupby('SG_UF').size().sort_values())
curaRJ2019 = int(df2019.query('EVOLUCAO == "Cura" and SG_UF == "RJ"').groupby('SG_UF').size().sort_values())
curaRN2019 = int(df2019.query('EVOLUCAO == "Cura" and SG_UF == "RN"').groupby('SG_UF').size().sort_values())
curaRS2019 = int(df2019.query('EVOLUCAO == "Cura" and SG_UF == "RS"').groupby('SG_UF').size().sort_values())
curaRO2019 = int(df2019.query('EVOLUCAO == "Cura" and SG_UF == "RO"').groupby('SG_UF').size().sort_values())
curaRR2019 = int(df2019.query('EVOLUCAO == "Cura" and SG_UF == "RR"').groupby('SG_UF').size().sort_values())
curaSC2019 = int(df2019.query('EVOLUCAO == "Cura" and SG_UF == "SC"').groupby('SG_UF').size().sort_values())
curaSP2019 = int(df2019.query('EVOLUCAO == "Cura" and SG_UF == "SP"').groupby('SG_UF').size().sort_values())
curaSE2019 = int(df2019.query('EVOLUCAO == "Cura" and SG_UF == "SE"').groupby('SG_UF').size().sort_values())
curaTO2019 = int(df2019.query('EVOLUCAO == "Cura" and SG_UF == "TO"').groupby('SG_UF').size().sort_values())

# %%
#############################################################################################################################
#########################################PREPARAÇÃO DOS DADOS 2020###########################################################
#############################################################################################################################

#Contagem de número de casos ignorados separados por estado ano 2020
igAC = int(df.query('EVOLUCAO == "Ignorado" and SG_UF == "AC"').groupby('SG_UF').size().sort_values())
igAL = int(df.query('EVOLUCAO == "Ignorado" and SG_UF == "AL"').groupby('SG_UF').size().sort_values())
igAP = int(df.query('EVOLUCAO == "Ignorado" and SG_UF == "AP"').groupby('SG_UF').size().sort_values())
igAM = int(df.query('EVOLUCAO == "Ignorado" and SG_UF == "AM"').groupby('SG_UF').size().sort_values())
igBA = int(df.query('EVOLUCAO == "Ignorado" and SG_UF == "BA"').groupby('SG_UF').size().sort_values())
igCE = int(df.query('EVOLUCAO == "Ignorado" and SG_UF == "CE"').groupby('SG_UF').size().sort_values())
igDF = int(df.query('EVOLUCAO == "Ignorado" and SG_UF == "DF"').groupby('SG_UF').size().sort_values())
igES = int(df.query('EVOLUCAO == "Ignorado" and SG_UF == "ES"').groupby('SG_UF').size().sort_values())
igGO = int(df.query('EVOLUCAO == "Ignorado" and SG_UF == "GO"').groupby('SG_UF').size().sort_values())
igMA = int(df.query('EVOLUCAO == "Ignorado" and SG_UF == "MA"').groupby('SG_UF').size().sort_values())
igMT = int(df.query('EVOLUCAO == "Ignorado" and SG_UF == "MT"').groupby('SG_UF').size().sort_values())
igMS = int(df.query('EVOLUCAO == "Ignorado" and SG_UF == "MS"').groupby('SG_UF').size().sort_values())
igMG = int(df.query('EVOLUCAO == "Ignorado" and SG_UF == "MG"').groupby('SG_UF').size().sort_values())
igPA = int(df.query('EVOLUCAO == "Ignorado" and SG_UF == "PA"').groupby('SG_UF').size().sort_values())
igPB = int(df.query('EVOLUCAO == "Ignorado" and SG_UF == "PB"').groupby('SG_UF').size().sort_values())
igPR = int(df.query('EVOLUCAO == "Ignorado" and SG_UF == "PR"').groupby('SG_UF').size().sort_values())
igPE = int(df.query('EVOLUCAO == "Ignorado" and SG_UF == "PE"').groupby('SG_UF').size().sort_values())
igPI = int(df.query('EVOLUCAO == "Ignorado" and SG_UF == "PI"').groupby('SG_UF').size().sort_values())
igRJ = int(df.query('EVOLUCAO == "Ignorado" and SG_UF == "RJ"').groupby('SG_UF').size().sort_values())
igRN = int(df.query('EVOLUCAO == "Ignorado" and SG_UF == "RN"').groupby('SG_UF').size().sort_values())
igRS = int(df.query('EVOLUCAO == "Ignorado" and SG_UF == "RS"').groupby('SG_UF').size().sort_values())
igRO = int(df.query('EVOLUCAO == "Ignorado" and SG_UF == "RO"').groupby('SG_UF').size().sort_values())
igRR = int(df.query('EVOLUCAO == "Ignorado" and SG_UF == "RR"').groupby('SG_UF').size().sort_values())
igSC = int(df.query('EVOLUCAO == "Ignorado" and SG_UF == "SC"').groupby('SG_UF').size().sort_values())
igSP = int(df.query('EVOLUCAO == "Ignorado" and SG_UF == "SP"').groupby('SG_UF').size().sort_values())
igSE = int(df.query('EVOLUCAO == "Ignorado" and SG_UF == "SE"').groupby('SG_UF').size().sort_values())
igTO = int(df.query('EVOLUCAO == "Ignorado" and SG_UF == "TO"').groupby('SG_UF').size().sort_values())

# %%
#############################################################################################################################
#########################################PREPARAÇÃO DOS DADOS 2019###########################################################
#############################################################################################################################

#Contagem de número de casos ignorados separados por estado ano 2019
igAC2019 = int(df2019.query('EVOLUCAO == "Ignorado" and SG_UF == "AC"').groupby('SG_UF').size().sort_values())
igAL2019 = int(df2019.query('EVOLUCAO == "Ignorado" and SG_UF == "AL"').groupby('SG_UF').size().sort_values())
igAP2019 = int(df2019.query('EVOLUCAO == "Ignorado" and SG_UF == "AP"').groupby('SG_UF').size().sort_values())
igAM2019 = int(df2019.query('EVOLUCAO == "Ignorado" and SG_UF == "AM"').groupby('SG_UF').size().sort_values())
igBA2019 = int(df2019.query('EVOLUCAO == "Ignorado" and SG_UF == "BA"').groupby('SG_UF').size().sort_values())
igCE2019 = int(df2019.query('EVOLUCAO == "Ignorado" and SG_UF == "CE"').groupby('SG_UF').size().sort_values())
igDF2019 = int(df2019.query('EVOLUCAO == "Ignorado" and SG_UF == "DF"').groupby('SG_UF').size().sort_values())
igES2019 = int(df2019.query('EVOLUCAO == "Ignorado" and SG_UF == "ES"').groupby('SG_UF').size().sort_values())
igGO2019 = int(df2019.query('EVOLUCAO == "Ignorado" and SG_UF == "GO"').groupby('SG_UF').size().sort_values())
igMA2019 = int(df2019.query('EVOLUCAO == "Ignorado" and SG_UF == "MA"').groupby('SG_UF').size().sort_values())
igMT2019 = int(df2019.query('EVOLUCAO == "Ignorado" and SG_UF == "MT"').groupby('SG_UF').size().sort_values())
igMS2019 = int(df2019.query('EVOLUCAO == "Ignorado" and SG_UF == "MS"').groupby('SG_UF').size().sort_values())
igMG2019 = int(df2019.query('EVOLUCAO == "Ignorado" and SG_UF == "MG"').groupby('SG_UF').size().sort_values())
igPA2019 = int(df2019.query('EVOLUCAO == "Ignorado" and SG_UF == "PA"').groupby('SG_UF').size().sort_values())
igPB2019 = int(df2019.query('EVOLUCAO == "Ignorado" and SG_UF == "PB"').groupby('SG_UF').size().sort_values())
igPR2019 = int(df2019.query('EVOLUCAO == "Ignorado" and SG_UF == "PR"').groupby('SG_UF').size().sort_values())
igPE2019 = int(df2019.query('EVOLUCAO == "Ignorado" and SG_UF == "PE"').groupby('SG_UF').size().sort_values())
igPI2019 = int(df2019.query('EVOLUCAO == "Ignorado" and SG_UF == "PI"').groupby('SG_UF').size().sort_values())
igRJ2019 = int(df2019.query('EVOLUCAO == "Ignorado" and SG_UF == "RJ"').groupby('SG_UF').size().sort_values())
igRN2019 = int(df2019.query('EVOLUCAO == "Ignorado" and SG_UF == "RN"').groupby('SG_UF').size().sort_values())
igRS2019 = int(df2019.query('EVOLUCAO == "Ignorado" and SG_UF == "RS"').groupby('SG_UF').size().sort_values())
igRO2019 = int(df2019.query('EVOLUCAO == "Ignorado" and SG_UF == "RO"').groupby('SG_UF').size().sort_values())
igRR2019 = int(df2019.query('EVOLUCAO == "Ignorado" and SG_UF == "RR"').groupby('SG_UF').size().sort_values())
igSC2019 = int(df2019.query('EVOLUCAO == "Ignorado" and SG_UF == "SC"').groupby('SG_UF').size().sort_values())
igSP2019 = int(df2019.query('EVOLUCAO == "Ignorado" and SG_UF == "SP"').groupby('SG_UF').size().sort_values())
igSE2019 = int(df2019.query('EVOLUCAO == "Ignorado" and SG_UF == "SE"').groupby('SG_UF').size().sort_values())
igTO2019 = int(df2019.query('EVOLUCAO == "Ignorado" and SG_UF == "TO"').groupby('SG_UF').size().sort_values())

# %%
#Plotando gráfico de óbitos por estado ano 2020
sO = pd.Series({"AC": obitoAC, "AL": obitoAL, "AP": obitoAP, "AM": obitoAM, "BA": obitoBA, "CE": obitoCE, "DF": obitoDF, 
               "ES": obitoES, "GO": obitoGO, "MA": obitoMA, "MT": obitoMT, "MS": obitoMT, "MG": obitoMG, "PA": obitoPA, 
               "PB": obitoPB, "PR": obitoPR, "PE": obitoPE, "PI": obitoPI, "RJ": obitoRJ, "RN": obitoRN, "RS": obitoRS, 
               "RO": obitoRO, "RR": obitoRR, "SC": obitoSC, "SP": obitoSP, "SE": obitoSE, "TO": obitoTO},
              name='article_id')
sO.plot(kind='bar', color='red',title='Números de óbitos por estado').set(xlabel = 'ESTADOS', ylabel='QUANTIDADE DE ÓBITOS')
plt.grid(linestyle='-.', linewidth='0.5', color='black')
plt.show()

# %%
#Plotando gráfico de óbitos por estado ano 2019
sO2019 = pd.Series({"AC": obitoAC2019, "AL": obitoAL2019, "AP": obitoAP2019, "AM": obitoAM2019, "BA": obitoBA2019, "CE": obitoCE2019, "DF": obitoDF2019, 
               "ES": obitoES2019, "GO": obitoGO2019, "MA": obitoMA2019, "MT": obitoMT2019, "MS": obitoMT2019, "MG": obitoMG2019, "PA": obitoPA2019, 
               "PB": obitoPB2019, "PR": obitoPR2019, "PE": obitoPE2019, "PI": obitoPI2019, "RJ": obitoRJ2019, "RN": obitoRN2019, "RS": obitoRS2019, 
               "RO": obitoRO2019, "RR": obitoRR2019, "SC": obitoSC2019, "SP": obitoSP2019, "SE": obitoSE2019, "TO": obitoTO2019},
              name='article_id')
sO2019.plot(kind='bar', color='red',title='Números de óbitos por estado').set(xlabel = 'ESTADOS', ylabel='QUANTIDADE DE ÓBITOS')
plt.grid(linestyle='-.', linewidth='0.5', color='black')
plt.show()

# %%
########################PLOTANDO GRÁFICO DE BARRAS ÓBITOS 2020X2019 ESTADOS########################

obito2020 = [obitoAC,obitoAL,obitoAP,obitoAM,obitoBA,obitoCE,obitoDF,obitoES,
             obitoGO,obitoMA,obitoMT,obitoMS,obitoMG,obitoPA,obitoPB,obitoPR,obitoPE,
             obitoPI,obitoRJ,obitoRN,obitoRS,obitoRO,obitoRR,obitoSC,obitoSP,obitoSE,obitoTO]
obito2019 = [obitoAC2019,obitoAL2019,obitoAP2019,obitoAM2019,obitoBA2019,obitoCE2019,obitoDF2019,obitoES2019,
             obitoGO2019,obitoMA2019,obitoMT2019,obitoMS2019,obitoMG2019,obitoPA2019,obitoPB2019,obitoPR2019,
             obitoPE2019,obitoPI2019,obitoRJ2019,obitoRN2019,obitoRS2019,obitoRO2019,obitoRR2019,obitoSC2019,
             obitoSP2019,obitoSE2019,obitoTO2019]


#largura da barra
barWidth = 0.25

#Aumentando o gráfico
plt.figure(figsize=(10,5))

#Definindo posição das barras
r1 = np.arange(len(obito2020))
r2 = [x + barWidth for x in r1]


#Dados e cor das barras
plt.bar(r1,obito2020,color="yellow",width = barWidth, label='2020')
plt.bar(r2,obito2019,color="blue",width = barWidth,label='2019')


#Legendas do gráfico
plt.xlabel("Estados")
plt.xticks([r + barWidth for r in range(len(obito2020))],["AC","AL","AP","AM","BA","CE","DF","ES","GO",
                                                          "MA","MT","MS","MG","PA","PB","PR","PE","PI","RJ",
                                                          "RN","RS","RO","RR","SC","SP","SE","TO"])
plt.ylabel("Número pessoas")
plt.title("Óbitos 2019 e 2020 por estado")

#Tracejado para facilitar a visualição dos dados
plt.grid(linestyle='-.', linewidth='0.5', color='black')

plt.legend()
plt.show()

# %%
#Plotando gráfico de curas por estado ano 2020
sC = pd.Series({"AC": curaAC, "AL": curaAL, "AP": curaAP, "AM": curaAM, "BA": curaBA, "CE": curaCE, "DF": curaDF, 
               "ES": curaES, "GO": curaGO, "MA": curaMA, "MT": curaMT, "MS": curaMT, "MG": curaMG, "PA": curaPA, 
               "PB": curaPB, "PR": curaPR, "PE": curaPE, "PI": curaPI, "RJ": curaRJ, "RN": curaRN, "RS": curaRS, 
               "RO": curaRO, "RR": curaRR, "SC": curaSC, "SP": curaSP, "SE": curaSE, "TO": curaTO},
              name='article_id')
sC.plot(kind='bar', color='blue',title='Números de curas por estado').set(xlabel = 'ESTADOS', ylabel='QUANTIDADE DE ÓBITOS')
plt.grid(linestyle='-.', linewidth='0.5', color='black')
plt.show()

# %%
#Plotando gráfico de curas por estado ano 2019
sC2019 = pd.Series({"AC": curaAC2019, "AL": curaAL2019, "AP": curaAP2019, "AM": curaAM2019, "BA": curaBA2019, "CE": curaCE2019, "DF": curaDF2019, 
               "ES": curaES2019, "GO": curaGO2019, "MA": curaMA2019, "MT": curaMT2019, "MS": curaMT2019, "MG": curaMG2019, "PA": curaPA2019, 
               "PB": curaPB2019, "PR": curaPR2019, "PE": curaPE2019, "PI": curaPI2019, "RJ": curaRJ2019, "RN": curaRN2019, "RS": curaRS2019, 
               "RO": curaRO2019, "RR": curaRR2019, "SC": curaSC2019, "SP": curaSP2019, "SE": curaSE2019, "TO": curaTO2019},
              name='article_id')
sC2019.plot(kind='bar', color='blue',title='Números de curas por estado').set(xlabel = 'ESTADOS', ylabel='QUANTIDADE DE ÓBITOS')
plt.grid(linestyle='-.', linewidth='0.5', color='black')
plt.show()

# %%
####################################PLOTANDO GRÁFICO DE BARRAS CURAS 2020X2019 ESTADOS#######################################

#Lista dos curas 2020 e 2019
curas2020 = [curaAC,curaAL,curaAP,curaAM,curaBA,curaCE,curaDF,curaES,curaGO,curaMA,curaMT,curaMS,curaMG,curaPA,curaPB,curaPR,curaPE,curaPI,curaRJ,curaRN,curaRS,curaRO,curaRR,curaSC,curaSP,curaSE,curaTO]
curas2019 = [curaAC2019,curaAL2019,curaAP2019,curaAM2019,curaBA2019,curaCE2019,curaDF2019,curaES2019,curaGO2019,curaMA2019,curaMT2019,curaMS2019,curaMG2019,curaPA2019,curaPB2019,curaPR2019,curaPE2019,curaPI2019,curaRJ2019,curaRN2019,curaRS2019,curaRO2019,curaRR2019,curaSC2019,curaSP2019,curaSE2019,curaTO2019]


#largura da barra
barWidth = 0.25

#Aumentando o gráfico
plt.figure(figsize=(10,5))

#Definindo posição das barras
r1 = np.arange(len(curas2020))
r2 = [x + barWidth for x in r1]


#Dados e cor das barras
plt.bar(r1,curas2020,color="yellow",width = barWidth, label='2020')
plt.bar(r2,curas2019,color="blue",width = barWidth,label='2019')


#Legendas do gráfico
plt.xlabel("Estados")
plt.xticks([r + barWidth for r in range(len(curas2020))],["AC","AL","AP","AM","BA","CE","DF","ES","GO",
                                                          "MA","MT","MS","MG","PA","PB","PR","PE","PI","RJ",
                                                          "RN","RS","RO","RR","SC","SP","SE","TO"])
plt.ylabel("Número pessoas")
plt.title("Curas 2019 e 2020 por estado")

#Tracejado para facilitar a visualição dos dados
plt.grid(linestyle='-.', linewidth='0.5', color='black')

plt.legend()
plt.show()

# %%
#Plotando gráfico de dados ignorados por estado 2020
sI = pd.Series({"AC": igAC, "AL": igAL, "AP": igAP, "AM": igAM, "BA": igBA, "CE": igCE, "DF": igDF, 
               "ES": igES, "GO":igGO, "MA": igMA, "MT": igMT, "MS": igMT, "MG": igMG, "PA": igPA, 
               "PB": igPB, "PR": igPR, "PE": igPE, "PI": igPI, "RJ": igRJ, "RN": igRN, "RS": igRS, 
               "RO": igRO, "RR": igRR, "SC": igSC, "SP": igSP, "SE": igSE, "TO": igTO},
              name='article_id')
sI.plot(kind='bar', color='green',title='Números de casos ignorados por estado').set(xlabel = 'ESTADOS', ylabel='QUANTIDADE DE ÓBITOS')
plt.grid(linestyle='-.', linewidth='0.5', color='black')
plt.show()

# %%
#Plotando gráfico de dados ignorados por estado 2019
sI2019 = pd.Series({"AC": igAC2019, "AL": igAL2019, "AP": igAP2019, "AM": igAM2019, "BA": igBA2019, "CE": igCE2019, "DF": igDF2019, 
               "ES": igES2019, "GO":igGO2019, "MA": igMA2019, "MT": igMT2019, "MS": igMT2019, "MG": igMG2019, "PA": igPA2019, 
               "PB": igPB2019, "PR": igPR2019, "PE": igPE2019, "PI": igPI2019, "RJ": igRJ2019, "RN": igRN2019, "RS": igRS2019, 
               "RO": igRO2019, "RR": igRR2019, "SC": igSC2019, "SP": igSP2019, "SE": igSE2019, "TO": igTO2019},
              name='article_id')
sI2019.plot(kind='bar', color='green',title='Números de casos ignorados por estado').set(xlabel = 'ESTADOS', ylabel='QUANTIDADE DE ÓBITOS')
plt.grid(linestyle='-.', linewidth='0.5', color='black')
plt.show()

# %%
########################PLOTANDO GRÁFICO DE BARRAS CASOS IGNORADOS 2020X2019 ESTADOS########################

ignorado2020 = [igAC,igAL,igAP,igAM,igBA,igCE,igDF,igES,igGO,igMA,igMT,igMS,igMG,igPA,igPB,igPR,igPE,igPI,igRJ,igRN,igRS,
                igRO,igRR,igSC,igSP,igSE,igTO]
ignorado2019 = [igAC2019,igAL2019,igAP2019,igAM2019,igBA2019,igCE2019,igDF2019,igES2019,igGO2019,igMA2019,igMT2019,igMS2019,
                igMG2019,igPA2019,igPB2019,igPR2019,igPE2019,igPI2019,igRJ2019,igRN2019,igRS2019,igRO2019,igRR2019,igSC2019,
                igSP2019,igSE2019,igTO2019]


#largura da barra
barWidth = 0.25

#Aumentando o gráfico
plt.figure(figsize=(10,5))

#Definindo posição das barras
r1 = np.arange(len(ignorado2020))
r2 = [x + barWidth for x in r1]


#Dados e cor das barras
plt.bar(r1,ignorado2020,color="yellow",width = barWidth, label='2020')
plt.bar(r2,ignorado2019,color="blue",width = barWidth,label='2019')


#Legendas do gráfico
plt.xlabel("Estados")
plt.xticks([r + barWidth for r in range(len(ignorado2020))],["AC","AL","AP","AM","BA","CE","DF","ES","GO",
                                                          "MA","MT","MS","MG","PA","PB","PR","PE","PI","RJ",
                                                          "RN","RS","RO","RR","SC","SP","SE","TO"])
plt.ylabel("Número pessoas")
plt.title("Casos ignorados 2019 e 2020 por estado")

#Tracejado para facilitar a visualição dos dados
plt.grid(linestyle='-.', linewidth='0.5', color='black')

plt.legend()
plt.show()

# %%
########################PLOTANDO GRÁFICO DE BARRAS 5 ESTADOS MAIS RICOS DO BRASIL########################
#Lista dos 5 estados mais ricos
curas = [curaSP,curaRJ,curaMG,curaRS,curaPR]
obitos = [obitoSP,obitoRJ,obitoMG,obitoRS,obitoPR]
ignorados = [igSP,igRJ,igMG,igRS,igPR]

#largura da barra
barWidth = 0.25

#Aumentando o gráfico
plt.figure(figsize=(10,5))

#Definindo posição das barras
r1 = np.arange(len(curas))
r2 = [x + barWidth for x in r1]
r3 = [x + barWidth for x in r2]

#Dados e cor das barras
plt.bar(r1,curas,color="blue",width = barWidth, label='Cura')
plt.bar(r2,obitos,color="red",width = barWidth,label='Óbito')
plt.bar(r3,ignorados,color="green",width = barWidth,label='Ignorado')

#Legendas do gráfico
plt.xlabel("Estados")
plt.xticks([r + barWidth for r in range(len(curas))],['SP','RJ','MG','RS','PR'])
plt.ylabel("Número pessoas")
plt.title("5 estados mais ricos do Brasil")

#Tracejado para facilitar a visualição dos dados
plt.grid(linestyle='-.', linewidth='0.5', color='black')

plt.legend()
plt.show()

# %%
########################PLOTANDO GRÁFICO DE PIZZA 5 ESTADOS MAIS RICOS DO BRASIL########################
estadosR = pd.DataFrame({'São Paulo': [curaSP, obitoSP , igSP],
                   'Rio de Janeiro': [curaRJ, obitoRJ , igRJ],
                   'Minas Gerais': [curaMG, obitoMG , igMG],
                   'Rio Grande do Sul': [curaRS, obitoRS , igRS],
                   'Paraná': [curaPR, obitoPR , igPR]},
                  index=['Cura', 'Obito', 'Ignorado'])
c = ['blue','red','green']
plot = estadosR.plot.pie(subplots=True, figsize=(20, 10), colors=c)

# %%
########################PLOTANDO GRÁFICO DE BARRAS 5 ESTADOS MAIS POBRES DO BRASIL########################
#Lista dos 5 estados mais pobres
curas = [curaRR,curaAC,curaAP,curaTO,curaPI]
obitos = [obitoRR,obitoAC,obitoAP,obitoTO,obitoPI]
ignorados = [igRR,igAC,igAP,igTO,igPI]

#largura da barra
barWidth = 0.25

#Aumentando o gráfico
plt.figure(figsize=(10,5))

#Definindo posição das barras
r1 = np.arange(len(curas))
r2 = [x + barWidth for x in r1]
r3 = [x + barWidth for x in r2]

#Dados e cor das barras
plt.bar(r1,curas,color="blue",width = barWidth, label='Cura')
plt.bar(r2,obitos,color="red",width = barWidth,label='Óbito')
plt.bar(r3,ignorados,color="green",width = barWidth,label='Ignorado')

#Legendas do gráfico
plt.xlabel("Estados")
plt.xticks([r + barWidth for r in range(len(curas))],['RR','AC','AP','TO','PI'])
plt.ylabel("Número pessoas")
plt.title("5 estados mais pobres do Brasil")

#Tracejado para facilitar a visualição dos dados
plt.grid(linestyle='-.', linewidth='0.5', color='black')

plt.legend()
plt.show()

# %%
########################PLOTANDO GRÁFICO DE PIZZA 5 ESTADOS MAIS POBRES DO BRASIL########################
estadosP = pd.DataFrame({'Roraima': [curaRR, obitoRR , igRR],
                   'Acre': [curaAC, obitoAC , igAC],
                   'Amapa': [curaAP, obitoAP , igAP],
                   'Tocantins': [curaTO, obitoTO , igTO],
                   'Piau': [curaPI, obitoPI , igPI]},
                  index=['Cura', 'Obito', 'Ignorado'])
c = ['blue','red','green']
plot = estadosP.plot.pie(subplots=True, figsize=(20, 10), colors=c)

# %%
#População estimada dos 5 estados mais ricos

popEstSP = 45919049
popEstRJ = 17264943
popEstMG = 21168943
popEstRS = 11377239
popEstPR = 11433957

#População estimada dos 5 estados mais pobres
popEstRR = 605761
popEstAC = 881935
popEstAP = 845731
popEstTO = 1572866
popEstPI = 3273227

# %%
#Calculando a razão de população estimada por morte dos 5 estados mais ricos

rzSP = (obitoSP*100)/popEstSP
rzRJ = (obitoRJ*100)/popEstRJ
rzMG = (obitoMG*100)/popEstMG
rzRS = (obitoRS*100)/popEstRS
rzPR = (obitoPR*100)/popEstPR

#Calculando a razão de população estimada por morte dos 5 estados mais pobres

rzRR = (obitoRR*100)/popEstRR
rzAC = (obitoAC*100)/popEstAC
rzAP = (obitoAP*100)/popEstAP
rzTO = (obitoTO*100)/popEstTO
rzPI = (obitoPI*100)/popEstPI

# %%
print("Redução da densidade populacional devido á Síndrome Respiratória Aguda Grave(incluindo dados da COVID-19) do estado de São Paulo: %.2f" % rzSP + "%.\n")
print("Redução da densidade populacional devido á Síndrome Respiratória Aguda Grave(incluindo dados da COVID-19) do estado do Rio de Janeiro: %.2f" % rzRJ + "%.\n")
print("Redução da densidade populacional devido á Síndrome Respiratória Aguda Grave(incluindo dados da COVID-19) do estado de Minas Gerais: %.2f" % rzMG + "%.\n")
print("Redução da densidade populacional devido á Síndrome Respiratória Aguda Grave(incluindo dados da COVID-19) do estado do Rio Grande do Sul: %.2f" % rzRS + "%.\n")
print("Redução da densidade populacional devido á Síndrome Respiratória Aguda Grave(incluindo dados da COVID-19) do estado do Paraná: %.2f" % rzPR + "%.\n")


print("Redução da densidade populacional devido á Síndrome Respiratória Aguda Grave(incluindo dados da COVID-19) do estado de Roraima: %.2f" % rzRR + "%.\n")
print("Redução da densidade populacional devido á Síndrome Respiratória Aguda Grave(incluindo dados da COVID-19) do estado do Acre: %.2f" % rzAC + "%.\n")
print("Redução da densidade populacional devido á Síndrome Respiratória Aguda Grave(incluindo dados da COVID-19) do estado do Amapá: %.2f" % rzAP + "%.\n")
print("Redução da densidade populacional devido á Síndrome Respiratória Aguda Grave(incluindo dados da COVID-19) do estado do Tocantins: %.2f" % rzTO + "%.\n")
print("Redução da densidade populacional devido á Síndrome Respiratória Aguda Grave(incluindo dados da COVID-19) do estado do Piauí: %.2f" % rzPI + "%.\n")
# Out:
# Redução da densidade populacional devido á Síndrome Respiratória Aguda Grave(incluindo dados da COVID-19) do estado de São Paulo: 0.06%.
#
# Redução da densidade populacional devido á Síndrome Respiratória Aguda Grave(incluindo dados da COVID-19) do estado do Rio de Janeiro: 0.08%.
#
# Redução da densidade populacional devido á Síndrome Respiratória Aguda Grave(incluindo dados da COVID-19) do estado de Minas Gerais: 0.02%.
#
# Redução da densidade populacional devido á Síndrome Respiratória Aguda Grave(incluindo dados da COVID-19) do estado do Rio Grande do Sul: 0.02%.
#
# Redução da densidade populacional devido á Síndrome Respiratória Aguda Grave(incluindo dados da COVID-19) do estado do Paraná: 0.02%.
#
# Redução da densidade populacional devido á Síndrome Respiratória Aguda Grave(incluindo dados da COVID-19) do estado de Roraima: 0.06%.
#
# Redução da densidade populacional devido á Síndrome Respiratória Aguda Grave(incluindo dados da COVID-19) do estado do Acre: 0.03%.
#
# ...

# %%
#Redução da densidade populacional devido á Síndrome Respiratória Aguda Grave(incluindo dados da COVID-19) do estado de São Paulo

labels = ['Não óbitos','Óbitos']
sizes = [(100-rzSP),rzSP]

explode = [0,0.1]

fig1,ax1 = plt.subplots()

c = ['lightblue','red']

ax1.pie(sizes,explode=explode, labels=labels, autopct='%1.2f%%', 
        shadow=True, startangle=90, colors=c)

ax1.axis('equal')

plt.title("Redução da densidade populacional devido á Síndrome Respiratória Aguda Grave(incluindo dados da COVID-19) do estado de São Paulo")

plt.show()

# %%
#Redução da densidade populacional devido á Síndrome Respiratória Aguda Grave(incluindo dados da COVID-19) do estado do Rio de Janeiro

labels = ['Não óbitos','Óbitos']
sizes = [(100-rzRJ),rzRJ]

explode = [0,0.1]

fig1,ax1 = plt.subplots()

c = ['lightblue','red']

ax1.pie(sizes,explode=explode, labels=labels, autopct='%1.2f%%', 
        shadow=True, startangle=90, colors=c)

ax1.axis('equal')

plt.title("Redução da densidade populacional devido á Síndrome Respiratória Aguda Grave(incluindo dados da COVID-19) do estado do Rio de Janeiro")

plt.show()

# %%
#Redução da densidade populacional devido á Síndrome Respiratória Aguda Grave(incluindo dados da COVID-19) do estado de Minas Gerais

labels = ['Não óbitos','Óbitos']
sizes = [(100-rzMG),rzMG]

explode = [0,0.1]

fig1,ax1 = plt.subplots()

c = ['lightblue','red']

ax1.pie(sizes,explode=explode, labels=labels, autopct='%1.2f%%', 
        shadow=True, startangle=90, colors=c)

ax1.axis('equal')

plt.title("Redução da densidade populacional devido á Síndrome Respiratória Aguda Grave(incluindo dados da COVID-19) do estado de Minas Gerais")

plt.show()

# %%
#Redução da densidade populacional devido á Síndrome Respiratória Aguda Grave(incluindo dados da COVID-19) do estado do Rio Grande do Sul

labels = ['Não óbitos','Óbitos']
sizes = [(100-rzRS),rzRS]

explode = [0,0.1]

fig1,ax1 = plt.subplots()

c = ['lightblue','red']

ax1.pie(sizes,explode=explode, labels=labels, autopct='%1.2f%%', 
        shadow=True, startangle=90, colors=c)

ax1.axis('equal')

plt.title("Redução da densidade populacional devido á Síndrome Respiratória Aguda Grave(incluindo dados da COVID-19) do estado do Rio Grande do Sul")

plt.show()

# %%
#Redução da densidade populacional devido á Síndrome Respiratória Aguda Grave(incluindo dados da COVID-19) do estado do Paraná

labels = ['Não óbitos','Óbitos']
sizes = [(100-rzPR),rzPR]

explode = [0,0.1]

fig1,ax1 = plt.subplots()

c = ['lightblue','red']

ax1.pie(sizes,explode=explode, labels=labels, autopct='%1.2f%%', 
        shadow=True, startangle=90, colors=c)

ax1.axis('equal')

plt.title("Redução da densidade populacional devido á Síndrome Respiratória Aguda Grave(incluindo dados da COVID-19) do estado do Paraná")

plt.show()

# %%
#Redução da densidade populacional devido á Síndrome Respiratória Aguda Grave(incluindo dados da COVID-19) do estado de Roraima

labels = ['Não óbitos','Óbitos']
sizes = [(100-rzRR),rzRR]

explode = [0,0.1]

fig1,ax1 = plt.subplots()

c = ['lightblue','red']

ax1.pie(sizes,explode=explode, labels=labels, autopct='%1.2f%%', 
        shadow=True, startangle=90, colors=c)

ax1.axis('equal')

plt.title("Redução da densidade populacional devido á Síndrome Respiratória Aguda Grave(incluindo dados da COVID-19) do estado de Roraima")

plt.show()

# %%
#Redução da densidade populacional devido á Síndrome Respiratória Aguda Grave(incluindo dados da COVID-19) do estado do Acre

labels = ['Não óbitos','Óbitos']
sizes = [(100-rzAC),rzAC]

explode = [0,0.1]

fig1,ax1 = plt.subplots()

c = ['lightblue','red']

ax1.pie(sizes,explode=explode, labels=labels, autopct='%1.2f%%', 
        shadow=True, startangle=90, colors=c)

ax1.axis('equal')

plt.title("Redução da densidade populacional devido á Síndrome Respiratória Aguda Grave(incluindo dados da COVID-19) do estado do Acre")

plt.show()

# %%
#Redução da densidade populacional devido á Síndrome Respiratória Aguda Grave(incluindo dados da COVID-19) do estado do Amapá

labels = ['Não óbitos','Óbitos']
sizes = [(100-rzAP),rzAP]

explode = [0,0.1]

fig1,ax1 = plt.subplots()

c = ['lightblue','red']

ax1.pie(sizes,explode=explode, labels=labels, autopct='%1.2f%%', 
        shadow=True, startangle=90, colors=c)

ax1.axis('equal')

plt.title("Redução da densidade populacional devido á Síndrome Respiratória Aguda Grave(incluindo dados da COVID-19) do estado do Amapá")

plt.show()

# %%
#Redução da densidade populacional devido á Síndrome Respiratória Aguda Grave(incluindo dados da COVID-19) do estado do Tocantins
labels = ['Não óbitos','Óbitos']
sizes = [(100-rzTO),rzTO]

explode = [0,0.1]

fig1,ax1 = plt.subplots()

c = ['lightblue','red']

ax1.pie(sizes,explode=explode, labels=labels, autopct='%1.2f%%', 
        shadow=True, startangle=90, colors=c)

ax1.axis('equal')

plt.title("Redução da densidade populacional devido á Síndrome Respiratória Aguda Grave(incluindo dados da COVID-19) do estado do Tocantins")

plt.show()

# %%
#Redução da densidade populacional devido á Síndrome Respiratória Aguda Grave(incluindo dados da COVID-19) do estado do Piauí

labels = ['Não óbitos','Óbitos']
sizes = [(100-rzPI),rzPI]

explode = [0,0.1]

fig1,ax1 = plt.subplots()

c = ['lightblue','red']

ax1.pie(sizes,explode=explode, labels=labels, autopct='%1.2f%%', 
        shadow=True, startangle=90, colors=c)

ax1.axis('equal')

plt.title("Redução da densidade populacional devido á Síndrome Respiratória Aguda Grave(incluindo dados da COVID-19) do estado do Piauí")

plt.show()
